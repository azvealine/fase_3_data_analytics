# %%
# Célula do Notebook: Declaração da Query CTAS do Athena (2023)

query_athena_2023 = """
CREATE TABLE tb_estruturada_2023
WITH (
    format = 'PARQUET',
    parquet_compression = 'SNAPPY',
    external_location = 's3://lab-980861984629/input/gold/2023/'
) AS
SELECT
    ROW_NUMBER() OVER () AS id,
    NULLIF(TRIM("_'p1_b_'__'genero'_#3"), '') AS genero,
    NULLIF(TRIM("_'p1_i_'__'estado_onde_mora'_#22"), '') AS estado_onde_mora,
    NULLIF(TRIM("_'p1_i_1_'__'uf_onde_mora'_#23"), '') AS uf_onde_mora,
    NULLIF(TRIM("_'p1_i_2_'__'regiao_onde_mora'_#24"), '') AS regiao_onde_mora,
    NULLIF(TRIM("_'p1_l_'__'nivel_de_ensino'_#27"), '') AS nivel_de_ensino,
    NULLIF(TRIM("_'p1_m_'__'área_de_formação'_#28"), '') AS area_de_formacao,
    NULLIF(TRIM("_'p2_b_'__'setor'_#30"), '') AS setor,
    NULLIF(TRIM("_'p2_f_'__'cargo_atual'_#34"), '') AS cargo_atual,
    NULLIF(TRIM("_'p2_g_'__'nivel'_#35"), '') AS nivel,
    NULLIF(TRIM("_'p2_h_'__'faixa_salarial'_#36"), '') AS faixa_salarial,
    NULLIF(TRIM("_'p2_i_'__'quanto_tempo_de_experiência_na_área_de_dados_você_tem?'_#37"), '') AS tempo_experiencia_dados,
    NULLIF(TRIM("_'p5_b_'__'qual_oportunidade_você_está_buscando?'_#245"), '') AS oportunidade_buscada,
    NULLIF(TRIM("_'p1_a_1_'__'faixa_idade'_#2"), '') AS faixa_idade,
    NULLIF(TRIM("_'P2_r_'__'Atualmente_qual_a_sua_forma_de_trabalho?'_#62"), '') as modelo_trabalho_atual,
    NULLIF(TRIM("_'P2_s_'__'Qual_a_forma_de_trabalho_ideal_para_você?'_#63"), '') as modelo_trabalho_ideal,
    NULLIF(TRIM("_'P3_b_'__'Quais_desses_papéis/cargos_fazem_parte_do_time__ou_chapter__de_dados_da_sua_empresa?'_#66"), '') as cargos_dados_empresa,
    NULLIF(TRIM("_'P3_b_1_'__'Analytics_Engineer'_#67"), '') as Analytics_Engineer,
    NULLIF(TRIM("_'P3_b_2_'__'Engenharia_de_Dados/Data_Engineer'_#68"), '') as Engenheiro_de_dados,
    NULLIF(TRIM("_'P3_b_3_'__'Analista_de_Dados/Data_Analyst'_#69"), '') as Analisa_de_dados,
    NULLIF(TRIM("_'P3_b_4_'__'Cientista_de_Dados/Data_Scientist'_#70"), '') as Cientista_de_dados,
    NULLIF(TRIM("_'P3_b_5_'__'Database_Administrator/DBA'_#71"), '') as Database_Administrator,
    NULLIF(TRIM("_'P3_b_6_'__'Analista_de_Business_Intelligence/BI'_#72"), '') as Analista_de_business,
    NULLIF(TRIM("_'P3_b_7_'__'Arquiteto_de_Dados/Data_Architect'_#73"), '') as Arquiteto_de_dados,
    NULLIF(TRIM("_'P3_b_8_'__'Data_Product_Manager/DPM'_#74"), '') as Product_manager,
    NULLIF(TRIM("_'P3_b_9_'__'Business_Analyst'_#75"), '') as Business_Analyst,
    CAST(NULL AS VARCHAR) as ML_Engineer,

    NULLIF(TRIM("_'p4_d_'__'quais_das_linguagens_listadas_abaixo_você_utiliza_no_trabalho?'_#143"), '') AS linguagens_utilizadas,
    NULLIF(TRIM("_'p4_d_1_'__'sql'_#144"), '') AS sql,
    NULLIF(TRIM("_'p4_d_2_'__'r_'_#145"), '') AS r,
    NULLIF(TRIM("_'p4_d_3_'__'python'_#146"), '') AS python,
    NULLIF(TRIM("_'p4_d_4_'__'c/c++/c#'_#147"), '') AS c_cpp_csharp,
    NULLIF(TRIM("_'p4_d_5_'__'.net'_#148"), '') AS dotnet,
    NULLIF(TRIM("_'p4_d_6_'__'java'_#149"), '') AS java,
    NULLIF(TRIM("_'p4_d_7_'__'julia'_#150"), '') AS julia,
    NULLIF(TRIM("_'p4_d_8_'__'sas/stata'_#151"), '') AS sas_stata,
    NULLIF(TRIM("_'p4_d_9_'__'visual_basic/vba'_#152"), '') AS visual_basic_vba,
    NULLIF(TRIM("_'p4_d_10_'__'scala'_#153"), '') AS scala,
    NULLIF(TRIM("_'p4_d_11_'__'matlab'_#154"), '') AS matlab,
    NULLIF(TRIM("_'p4_d_12_'__'rust'_#155"), '') AS rust,
    NULLIF(TRIM("_'p4_d_13_'__'php'_#156"), '') AS php,
    NULLIF(TRIM("_'p4_d_14_'__'javascript'_#157"), '') AS javascript,
    NULLIF(TRIM("_'p4_d_15_'__'não_utilizo_nenhuma_linguagem'_#158"), '') AS nenhuma_linguagem,
    NULLIF(TRIM("_'p4_e_'__'entre_as_linguagens_listadas_abaixo__qual_é_a_que_você_mais_utiliza_no_trabalho?'_#159"), '') AS linguagem_principal,
    NULLIF(TRIM("_'p1_c_'__'cor/raca/etnia'_#4"), '') AS cor_raca_etnia,

    NULLIF(TRIM("_'p4_g_'__'quais_dos_bancos_de_dados/fontes_de_dados_listados_abaixo_você_utiliza_no_trabalho?'_#161"), '') AS bancos_fontes_utilizados,
    NULLIF(TRIM("_'p4_g_1_'__'mysql'_#162"), '') AS mysql,
    NULLIF(TRIM("_'p4_g_2_'__'oracle'_#163"), '') AS oracle,
    NULLIF(TRIM("_'p4_g_3_'__'sql_server'_#164"), '') AS sql_server,
    NULLIF(TRIM("_'p4_g_4_'__'amazon_aurora_ou_rds'_#165"), '') AS amazon_aurora_rds,
    NULLIF(TRIM("_'p4_g_5_'__'dynamodb'_#166"), '') AS dynamodb,
    NULLIF(TRIM("_'p4_g_6_'__'coachdb'_#167"), '') AS coachdb,
    NULLIF(TRIM("_'p4_g_7_'__'cassandra'_#168"), '') AS cassandra,
    NULLIF(TRIM("_'p4_g_8_'__'mongodb'_#169"), '') AS mongodb,
    NULLIF(TRIM("_'p4_g_9_'__'mariadb'_#170"), '') AS mariadb,
    NULLIF(TRIM("_'p4_g_10_'__'datomic'_#171"), '') AS datomic,
    NULLIF(TRIM("_'p4_g_11_'__'s3'_#172"), '') AS s3,
    NULLIF(TRIM("_'p4_g_12_'__'postgresql'_#173"), '') AS postgresql,
    NULLIF(TRIM("_'p4_g_13_'__'elasticsearch'_#174"), '') AS elasticsearch,
    NULLIF(TRIM("_'p4_g_14_'__'db2'_#175"), '') AS db2,
    NULLIF(TRIM("_'p4_g_15_'__'microsoft_access'_#176"), '') AS microsoft_access,
    NULLIF(TRIM("_'p4_g_16_'__'sqlite'_#177"), '') AS sqlite,
    NULLIF(TRIM("_'p4_g_17_'__'sybase'_#178"), '') AS sybase,
    NULLIF(TRIM("_'p4_g_18_'__'firebase'_#179"), '') AS firebase,
    NULLIF(TRIM("_'p4_g_19_'__'vertica'_#180"), '') AS vertica,
    NULLIF(TRIM("_'p4_g_20_'__'redis'_#181"), '') AS redis,
    NULLIF(TRIM("_'p4_g_21_'__'neo4j'_#182"), '') AS neo4j,
    NULLIF(TRIM("_'p4_g_22_'__'google_bigquery'_#183"), '') AS google_bigquery,
    NULLIF(TRIM("_'p4_g_23_'__'google_firestore'_#184"), '') AS google_firestore,
    NULLIF(TRIM("_'p4_g_24_'__'amazon_redshift'_#185"), '') AS amazon_redshift,
    NULLIF(TRIM("_'p4_g_25_'__'amazon_athena'_#186"), '') AS amazon_athena,
    NULLIF(TRIM("_'p4_g_26_'__'snowflake'_#187"), '') AS snowflake,
    NULLIF(TRIM("_'p4_g_27_'__'databricks'_#188"), '') AS databricks,
    NULLIF(TRIM("_'p4_g_28_'__'hbase'_#189"), '') AS hbase,
    NULLIF(TRIM("_'p4_g_29_'__'presto'_#190"), '') AS presto,
    NULLIF(TRIM("_'p4_g_30_'__'splunk'_#191"), '') AS splunk,
    NULLIF(TRIM("_'p4_g_31_'__'sap_hana'_#192"), '') AS sap_hana,
    NULLIF(TRIM("_'p4_g_32_'__'hive'_#193"), '') AS hive,
    NULLIF(TRIM("_'p4_g_33_'__'firebird'_#194"), '') AS firebird,

    NULLIF(TRIM("_'P4_h_'__'Dentre_as_opções_listadas__qual_sua_Cloud_preferida?'_#195"), '') as cloud_utilizada,
    NULLIF(TRIM("_'P4_h_2_'__'Amazon_Web_Services__AWS_'_#197"), '') as AWS_cloud,
    NULLIF(TRIM("_'P4_h_3_'__'Google_Cloud__GCP_'_#198"), '') as GCP_cloud,
    NULLIF(TRIM("_'P4_h_1_'__'Azure__Microsoft_'_#196"), '') as Azure_cloud,
    NULLIF(TRIM("_'P4_h_4_'__'Oracle_Cloud'_#199"), '') AS Oracle_cloud,
    NULLIF(TRIM("_'P4_h_5_'__'IBM'_#200"), '') as IBM,
    NULLIF(TRIM("_'P4_h_6_'__'Servidores_On_Premise/Não_utilizamos_Cloud'_#201"), '') as sem_cloud,
    NULLIF(TRIM("_'P4_h_7_'__'Cloud_Própria'_#202"), '') as cloud_propria,
    NULLIF(TRIM("_'P4_i_'__'Cloud_preferida'_#203"), '') as cloud_preferida,

    NULLIF(TRIM("_'p6_b_'__'quais_as_ferramentas/tecnologias_de_etl_que_você_utiliza_no_trabalho_como_data_engineer?'_#258"), '') AS ferramentas_etl,
    NULLIF(TRIM("_'p6_b_1_'__'scripts_python'_#259"), '') AS scripts_python,
    NULLIF(TRIM("_'p6_b_2_'__'sql_&_stored_procedures'_#260"), '') AS sql_stored_procedures,
    NULLIF(TRIM("_'p6_b_3_'__'apache_airflow'_#261"), '') AS apache_airflow,
    NULLIF(TRIM("_'p6_b_4_'__'apache_nifi'_#262"), '') AS apache_nifi,
    NULLIF(TRIM("_'p6_b_5_'__'luigi'_#263"), '') AS luigi,
    NULLIF(TRIM("_'p6_b_6_'__'aws_glue'_#264"), '') AS aws_glue,
    NULLIF(TRIM("_'p6_b_7_'__'talend'_#265"), '') AS talend,
    NULLIF(TRIM("_'p6_b_8_'__'pentaho'_#266"), '') AS pentaho,
    NULLIF(TRIM("_'p6_b_9_'__'alteryx'_#267"), '') AS alteryx,
    NULLIF(TRIM("_'p6_b_10_'__'stitch'_#268"), '') AS stitch,
    NULLIF(TRIM("_'p6_b_11_'__'fivetran'_#269"), '') AS fivetran,
    NULLIF(TRIM("_'p6_b_12_'__'google_dataflow'_#270"), '') AS google_dataflow,
    NULLIF(TRIM("_'p6_b_13_'__'oracle_data_integrator'_#271"), '') AS oracle_data_integrator,
    NULLIF(TRIM("_'p6_b_14_'__'ibm_datastage'_#272"), '') AS ibm_datastage,
    NULLIF(TRIM("_'p6_b_15_'__'sap_bw_etl'_#273"), '') AS sap_bw_etl,
    NULLIF(TRIM("_'p6_b_16_'__'sql_server_integration_services__ssis__#274"), '') AS sql_server_integration_services_ssis,
    NULLIF(TRIM("_'p6_b_17_'__'sas_data_integration'_#275"), '') AS sas_data_integration,
    NULLIF(TRIM("_'p6_b_18_'__'qlik_sense'_#276"), '') AS qlik_sense,
    NULLIF(TRIM("_'p6_b_19_'__'knime'_#277"), '') AS knime,
    NULLIF(TRIM("_'p6_b_20_'__'databricks'_#278"), '') AS databricks_etl,

    NULLIF(TRIM("_'p4_l_'__'qual_o_tipo_de_uso_de_ai_generativa_e_llms_na_empresa'_#229"), '') AS uso_ia_empresa,
    NULLIF(TRIM("_'p4_l_1_'__'colaboradores_usando_ai_generativa_de_forma_independente_e_descentralizada'_#230"), '') AS ia_independente_descentralizada,
    NULLIF(TRIM("_'p4_l_2_'__'direcionamento_centralizado_do_uso_de_ai_generativa'_#231"), '') AS ia_direcionamento_centralizado,
    NULLIF(TRIM("_'p4_l_3_'__'desenvolvedores_utilizando_copilots'_#232"), '') AS desenvolvedores_copilot,
    NULLIF(TRIM("_'p4_l_4_'__'ai_generativa_e_llms_para_melhorar_produtos_externos_para_os_clientes_finais'_#233"), '') AS ia_produtos_externos,
    NULLIF(TRIM("_'p4_l_5_'__'ai_generativa_e_llms_para_melhorar_produtos_internos_para_os_colaboradores'_#234"), '') AS ia_produtos_internos,
    NULLIF(TRIM("_'p4_l_6_'__'ia_generativa_e_llms_como_principal_frente_do_negócio'_#235"), '') AS ia_principal_frente_negocio,
    NULLIF(TRIM("_'p4_l_7_'__'ia_generativa_e_llms_não_é_prioridade'_#236"), '') AS ia_nao_prioridade,
    NULLIF(TRIM("_'p4_l_8_'__'não_sei_opinar_sobre_o_uso_de_ia_generativa_e_llms_na_empresa'_#237"), '') AS ia_nao_sei_opinar,

    NULLIF(TRIM("_'p4_m_'__'utiliza_chatgpt_ou_llms_no_trabalho?'_#238"), '') AS utiliza_chatgpt_llms,
    NULLIF(TRIM("_'p4_m_1_'__'não_uso_soluções_de_ai_generativa_com_foco_em_produtividade'_#239"), '') AS ia_nao_utiliza_produtividade,
    NULLIF(TRIM("_'p4_m_2_'__'uso_soluções_gratuitas_de_ai_generativa_com_foco_em_produtividade'_#240"), '') AS ia_solucoes_gratuitas,
    NULLIF(TRIM("_'p4_m_3_'__'uso_e_pago_pelas_soluções_de_ai_generativa_com_foco_em_produtividade'_#241"), '') AS ia_paga_usuario,
    NULLIF(TRIM("_'p4_m_4_'__'a_empresa_que_trabalho_paga_pelas_soluções_de_ai_generativa_com_foco_em_produtividade'_#242"), '') AS ia_paga_empresa,
    NULLIF(TRIM("_'p4_m_5_'__'uso_soluções_do_tipo_copilot'_#243"), '') AS usa_copilot,

    NULLIF(TRIM("_'p3_g_'__'motivos_que_levam_a_empresa_a_não_usar_ai_genrativa_e_llms'_#113"), '') AS motivos_nao_uso_ia,
    NULLIF(TRIM("_'p3_g_1_'__'falta_de_compreensão_dos_casos_de_uso'_#114"), '') AS falta_compreensao_casos_uso,
    NULLIF(TRIM("_'p3_g_2_'__'falta_de_confiabilidade_das_saídas__alucinação_dos_modelos_'_#115"), '') AS falta_confiabilidade_saidas,
    NULLIF(TRIM("_'p3_g_3_'__'incerteza_em_relação_a_regulamentação'_#116"), '') AS incerteza_regulamentacao,
    NULLIF(TRIM("_'p3_g_4_'__'preocupações_com_segurança_e_privacidade_de_dados'_#117"), '') AS preocupacoes_seguranca_privacidade,
    NULLIF(TRIM("_'p3_g_5_'__'retorno_sobre_investimento__roi__não_comprovado_de_ia_generativa'_#118"), '') AS roi_nao_comprovado_ia,
    NULLIF(TRIM("_'p3_g_6_'__'dados_da_empresa_não_estão_prontos_para_uso_de_ia_generativa'_#119"), '') AS dados_empresa_nao_prontos_ia,
    NULLIF(TRIM("_'p3_g_7_'__'falta_de_expertise_ou_falta_de_recursos'_#120"), '') AS falta_expertise_recursos,
    NULLIF(TRIM("_'p3_g_8_'__'alta_direção_da_empresa_não_vê_valor_ou_não_vê_como_prioridade'_#121"), '') AS alta_direcao_nao_ve_valor,
    NULLIF(TRIM("_'p3_g_9_'__'preocupações_com_propriedade_intelectual'_#122"), '') AS preocupacoes_propriedade_intelectual

FROM tb_profissionais_2023;
"""

print(query_athena_2023)
