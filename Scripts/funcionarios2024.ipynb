# %%
# Célula do Notebook: Declaração da Query CTAS do Athena (2024)

query_athena_2024 = """
CREATE TABLE tb_estruturada_2024
WITH (
    format = 'PARQUET',
    parquet_compression = 'SNAPPY',
    external_location = 's3://lab-980861984629/input/gold/2024/'
) AS
SELECT
    ROW_NUMBER() OVER () AS id,
    NULLIF(TRIM("1.b_genero"), '') AS genero,
    NULLIF(TRIM("1.i_estado_onde_mora"), '') AS estado_onde_mora,
    NULLIF(TRIM("1.i.1_uf_onde_mora"), '') AS uf_onde_mora,
    NULLIF(TRIM("1.i.2_regiao_onde_mora"), '') AS regiao_onde_mora,
    NULLIF(TRIM("1.l_nivel_de_ensino"), '') AS nivel_de_ensino,
    NULLIF(TRIM("1.m_área_de_formação"), '') AS area_de_formacao,
    NULLIF(TRIM("2.b_setor"), '') AS setor,
    NULLIF(TRIM("2.f_cargo_atual"), '') AS cargo_atual,
    NULLIF(TRIM("2.g_nivel"), '') AS nivel,
    NULLIF(TRIM("2.h_faixa_salarial"), '') AS faixa_salarial,
    NULLIF(TRIM("2.i_tempo_de_experiencia_em_dados"), '') AS tempo_experiencia_dados,
    NULLIF(TRIM("5.b_oportunidade_buscada"), '') AS oportunidade_buscada,
    NULLIF(TRIM("1.a.1_faixa_idade"), '') as faixa_idade,
    NULLIF(TRIM("2.r_modelo_de_trabalho_atual"), '') as modelo_trabalho_atual,
    NULLIF(TRIM("2.s_modelo_de_trabalho_ideal"), '') as modelo_trabalho_ideal,
    NULLIF(TRIM("3.b_cargos_no_time_de_dados_da_empresa"), '') as cargos_dados_empresa,
    NULLIF(TRIM("3.b.1_Analytics_Engineer#30"), '') as Analytics_Engineer,
    NULLIF(TRIM("3.b.2_Engenharia_de_Dados/Data_Engineer#31"), '') as Engenheiro_de_dados,
    NULLIF(TRIM("3.b.3_Analista_de_Dados/Data_Analyst#32"), '') as Analisa_de_dados,
    NULLIF(TRIM("3.b.4_Cientista_de_Dados/Data_Scientist#33"), '') as Cientista_de_dados,
    NULLIF(TRIM("3.b.5_Database_Administrator/DBA#34"), '') as Database_Administrator,
    NULLIF(TRIM("3.b.6_Analista_de_Business_Intelligence/BI#35"), '') as Analista_de_business,
    NULLIF(TRIM("3.b.7_Arquiteto_de_Dados/Data_Architect#36"), '') as Arquiteto_de_dados,
    NULLIF(TRIM("3.b.8_Data_Product_Manager/DPM#37"), '') as Product_manager,
    NULLIF(TRIM("3.b.9_Business_Analyst#38"), '') as Business_Analyst,
    NULLIF(TRIM("3.b.10_ML_Engineer/AI_Engineer#39"), '') as ML_Engineer,

    NULLIF(TRIM("4.d_linguagem_de_programacao__dia_a_dia_#89"), '') AS linguagens_utilizadas,
    NULLIF(TRIM("4.d.1_SQL"), '') AS sql,
    NULLIF(TRIM("4.d.2_R"), '') AS r,
    NULLIF(TRIM("4.d.3_Python"), '') AS python,
    NULLIF(TRIM("4.d.4_C/C++/C#"), '') AS c_cpp_csharp,
    NULLIF(TRIM("4.d.5_.NET"), '') AS dotnet,
    NULLIF(TRIM("4.d.6_Java"), '') AS java,
    NULLIF(TRIM("4.d.7_Julia"), '') AS julia,
    NULLIF(TRIM("4.d.8_SAS/Stata"), '') AS sas_stata,
    NULLIF(TRIM("4.d.9_Visual_Basic/VBA#90"), '') AS visual_basic_vba,
    NULLIF(TRIM("4.d.10_Scala"), '') AS scala,
    NULLIF(TRIM("4.d.11_Matlab"), '') AS matlab,
    NULLIF(TRIM("4.d.12_Rust"), '') AS rust,
    NULLIF(TRIM("4.d.13_PHP"), '') AS php,
    NULLIF(TRIM("4.d.14_JavaScript"), '') AS javascript,
    NULLIF(TRIM("4.d.15_Não_utilizo_nenhuma_das_linguagens_listadas#91"), '') AS nenhuma_linguagem,
    NULLIF(TRIM("4.e_linguagem_mais_usada"), '') AS linguagem_principal,
    NULLIF(TRIM("1.c_cor/raca/etnia"), '') AS cor_raca_etnia,

    NULLIF(TRIM("4.g_banco_de_dados__dia_a_dia_#92"), '') AS bancos_fontes_utilizados,
    NULLIF(TRIM("4.g.1_MySQL"), '') AS mysql,
    NULLIF(TRIM("4.g.2_Oracle"), '') AS oracle,
    NULLIF(TRIM("4.g.3_SQL_SERVER#93"), '') AS sql_server,
    NULLIF(TRIM("4.g.4_Amazon_Aurora_ou_RDS#94"), '') AS amazon_aurora_rds,
    NULLIF(TRIM("4.g.5_DynamoDB"), '') AS dynamodb,
    NULLIF(TRIM("4.g.6_CoachDB"), '') AS coachdb,
    NULLIF(TRIM("4.g.7_Cassandra"), '') AS cassandra,
    NULLIF(TRIM("4.g.8_MongoDB"), '') AS mongodb,
    NULLIF(TRIM("4.g.9_MariaDB"), '') AS mariadb,
    NULLIF(TRIM("4.g.10_Datomic"), '') AS datomic,
    NULLIF(TRIM("4.g.11_S3"), '') AS s3,
    NULLIF(TRIM("4.g.12_PostgreSQL"), '') AS postgresql,
    NULLIF(TRIM("4.g.13_ElasticSearch"), '') AS elasticsearch,
    NULLIF(TRIM("4.g.14_DB2"), '') AS db2,
    NULLIF(TRIM("4.g.15_Microsoft_Access#95"), '') AS microsoft_access,
    NULLIF(TRIM("4.g.16_SQLite"), '') AS sqlite,
    NULLIF(TRIM("4.g.17_Sybase"), '') AS sybase,
    NULLIF(TRIM("4.g.18_Firebase"), '') AS firebase,
    NULLIF(TRIM("4.g.19_Vertica"), '') AS vertica,
    NULLIF(TRIM("4.g.20_Redis"), '') AS redis,
    NULLIF(TRIM("4.g.21_Neo4J"), '') AS neo4j,
    NULLIF(TRIM("4.g.22_Google_BigQuery#96"), '') AS google_bigquery,
    NULLIF(TRIM("4.g.23_Google_Firestore#97"), '') AS google_firestore,
    NULLIF(TRIM("4.g.24_Amazon_Redshift#98"), '') AS amazon_redshift,
    NULLIF(TRIM("4.g.25_Amazon_Athena#99"), '') AS amazon_athena,
    NULLIF(TRIM("4.g.26_Snowflake"), '') AS snowflake,
    NULLIF(TRIM("4.g.27_Databricks"), '') AS databricks,
    NULLIF(TRIM("4.g.28_HBase"), '') AS hbase,
    NULLIF(TRIM("4.g.29_Presto"), '') AS presto,
    NULLIF(TRIM("4.g.30_Splunk"), '') AS splunk,
    NULLIF(TRIM("4.g.31_SAP_HANA#100"), '') AS sap_hana,
    NULLIF(TRIM("4.g.32_Hive"), '') AS hive,
    NULLIF(TRIM("4.g.33_Firebird"), '') AS firebird,

    NULLIF(TRIM("4.h_cloud__dia_a_dia_#101"), '') as cloud_utilizada,
    NULLIF(TRIM("4.h.1_Amazon_Web_Services__AWS_#102"), '') as AWS_cloud,
    NULLIF(TRIM("4.h.2_Google_Cloud__GCP_#103"), '') as GCP_cloud,
    NULLIF(TRIM("4.h.3_Azure__Microsoft_#104"), '') as Azure_cloud,
    NULLIF(TRIM("4.h.4_Oracle_Cloud#105"), '') AS Oracle_cloud,
    NULLIF(TRIM("4.h.5_IBM"), '') as IBM,
    NULLIF(TRIM("4.h.6_Servidores_On_Premise/Não_utilizamos_Cloud#106"), '') as sem_cloud,
    NULLIF(TRIM("4.h.7_Cloud_Própria#107"), '') as cloud_propria,
    NULLIF(TRIM("4.i_cloud_preferida"), '') as cloud_preferida,

    NULLIF(TRIM("6.b_ferramentas_etl_de"), '') AS ferramentas_etl,
    NULLIF(TRIM("6.b.1_Scripts_Python#141"), '') AS scripts_python,
    NULLIF(TRIM("6.b.2_SQL_&_Stored_Procedures#142"), '') AS sql_stored_procedures,
    NULLIF(TRIM("6.b.3_Apache_Airflow#143"), '') AS apache_airflow,
    NULLIF(TRIM("6.b.4_Apache_NiFi#144"), '') AS apache_nifi,
    NULLIF(TRIM("6.b.5_Luigi"), '') AS luigi,
    NULLIF(TRIM("6.b.6_AWS_Glue#145"), '') AS aws_glue,
    NULLIF(TRIM("6.b.7_Talend"), '') AS talend,
    NULLIF(TRIM("6.b.8_Pentaho"), '') AS pentaho,
    NULLIF(TRIM("6.b.9_Alteryx"), '') AS alteryx,
    NULLIF(TRIM("6.b.10_Stitch"), '') AS stitch,
    NULLIF(TRIM("6.b.11_Fivetran"), '') AS fivetran,
    NULLIF(TRIM("6.b.12_Google_Dataflow#146"), '') AS google_dataflow,
    NULLIF(TRIM("6.b.13_Oracle_Data_Integrator#147"), '') AS oracle_data_integrator,
    NULLIF(TRIM("6.b.14_IBM_DataStage#148"), '') AS ibm_datastage,
    NULLIF(TRIM("6.b.15_SAP_BW_ETL#149"), '') AS sap_bw_etl,
    NULLIF(TRIM("6.b.16_SQL_Server_Integration_Services__SSIS_#150"), '') AS sql_server_integration_services_ssis,
    NULLIF(TRIM("6.b.17_SAS_Data_Integration#151"), '') AS sas_data_integration,
    NULLIF(TRIM("6.b.18_Qlik_Sense#152"), '') AS qlik_sense,
    NULLIF(TRIM("6.b.19_Knime"), '') AS knime,
    NULLIF(TRIM("6.b.20_Databricks"), '') AS databricks_etl,

    NULLIF(TRIM("4.l_tipo_de_uso_de_ai_generativa_e_llm_na_empresa"), '') AS uso_ia_empresa,
    NULLIF(TRIM("4.l.1_Colaboradores_usando_AI_generativa_de_forma_independente_e_descentralizada#119"), '') AS ia_independente_descentralizada,
    NULLIF(TRIM("4.l.2_Direcionamento_centralizado_do_uso_de_AI_generativa#120"), '') AS ia_direcionamento_centralizado,
    NULLIF(TRIM("4.l.3_Desenvolvedores_utilizando_Copilots#121"), '') AS desenvolvedores_copilot,
    NULLIF(TRIM("4.l.4_AI_Generativa_e_LLMs_para_melhorar_produtos_externos_para_os_clientes_finais#122"), '') AS ia_produtos_externos,
    NULLIF(TRIM("4.l.5_AI_Generativa_e_LLMs_para_melhorar_produtos_internos_para_os_colaboradores#123"), '') AS ia_produtos_internos,
    NULLIF(TRIM("4.l.6_IA_Generativa_e_LLMs_como_principal_frente_do_negócio#124"), '') AS ia_principal_frente_negocio,
    NULLIF(TRIM("4.l.7_IA_Generativa_e_LLMs_não_é_prioridade#125"), '') AS ia_nao_prioridade,
    NULLIF(TRIM("4.l.8_Não_sei_opinar_sobre_o_uso_de_IA_Generativa_e_LLMs_na_empresa#126"), '') AS ia_nao_sei_opinar,

    NULLIF(TRIM("4.m_usa_chatgpt_ou_copilot_no_trabalho?"), '') AS utiliza_chatgpt_llms,
    NULLIF(TRIM("4.m.1_Não_uso_soluções_de_AI_Generativa_com_foco_em_produtividade#127"), '') AS ia_nao_utiliza_produtividade,
    NULLIF(TRIM("4.m.2_Uso_soluções_gratuitas_de_AI_Generativa_com_foco_em_produtividade#128"), '') AS ia_solucoes_gratuitas,
    NULLIF(TRIM("4.m.3_Uso_e_pago_pelas_soluções_de_AI_Generativa_com_foco_em_produtividade#129"), '') AS ia_paga_usuario,
    NULLIF(TRIM("4.m.4_A_empresa_que_trabalho_paga_pelas_soluções_de_AI_Generativa_com_foco_em_produtividade#130"), '') AS ia_paga_empresa,
    NULLIF(TRIM("4.m.5_Uso_soluções_do_tipo_Copilot#131"), '') AS usa_copilot,

    NULLIF(TRIM("3.g_motivos_para_não_usar_ai_generativa_e_llm"), '') AS motivos_nao_uso_ia,
    NULLIF(TRIM("3.g.1_Falta_de_compreensão_dos_casos_de_uso#73"), '') AS falta_compreensao_casos_uso,
    NULLIF(TRIM("3.g.2_Falta_de_confiabilidade_das_saídas__alucinação_dos_modelos_#74"), '') AS falta_confiabilidade_saidas,
    NULLIF(TRIM("3.g.3_Incerteza_em_relação_a_regulamentação#75"), '') AS incerteza_regulamentacao,
    NULLIF(TRIM("3.g.4_Preocupações_com_segurança_e_privacidade_de_dados#76"), '') AS preocupacoes_seguranca_privacidade,
    NULLIF(TRIM("3.g.5_Retorno_sobre_investimento__ROI__não_comprovado_de_IA_Generativa#77"), '') AS roi_nao_comprovado_ia,
    NULLIF(TRIM("3.g.6_Dados_da_empresa_não_estão_prontos_para_uso_de_IA_Generativa#78"), '') AS dados_empresa_nao_prontos_ia,
    NULLIF(TRIM("3.g.7_Falta_de_expertise_ou_falta_de_recursos#79"), '') AS falta_expertise_recursos,
    NULLIF(TRIM("3.g.8_Alta_direção_da_empresa_não_vê_valor_ou_não_vê_como_prioridade#80"), '') AS alta_direcao_nao_ve_valor,
    NULLIF(TRIM("3.g.9_Preocupações_com_propriedade_intelectual#81"), '') AS preocupacoes_propriedade_intelectual

FROM tb_profissionais_2024;
"""

print(query_athena_2024)
